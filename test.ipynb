# %% [markdown]
# ```python
# import dista1
# ```

# %%
from elasticsearch import Elasticsearch
from elasticsearch import AuthenticationException
import json
import sys
import os
from bs4 import BeautifulSoup
from lxml import etree

with open("credentials.json", "r") as f:
    credentials = json.load(f)

with open("mapping.json", "r") as f:
    mapping = json.load(f)

# %% [markdown]
# # **Testing the XML files**
# ---

# %%
user_input = input("Enter something: ") + ".xml"
print(user_input)
path = os.path.join("collection", user_input)
# Out:
# cf74.xml

# %%
import re

with open(path, "r") as f:
    contents = f.read()
    res = re.sub(r'<\s*/?\s*?>', '', contents)
    res = re.split(r'(?=<RECORD>)', res)
    sel = int(input("Choose record:"))
    print(res[sel])
# Out:
# <RECORD>
# <PAPERNUM>PN74012</PAPERNUM>
# <CITATIONS>
# <CITE num="1" author="LZEL A              PR" publication="ACTITIONER                   2" d1="14" d2="76 9" d3="5"/>
# <CITE num="2" author="WARNER JO" publication="ARCH DIS CHILD" d1="51" d2="507" d3="976"/>
# <CITE num="3" author="STERN RC" publication="J PEDIATR" d1="89" d2="406" d3="976"/>
# <CITE num="4" author="GALANT SP" publication="AM REV RESPIR DIS" d1="114" d2="325" d3="976"/>
# <CITE num="5" author="PARTINGTON MW" publication="ARCH DIS CHILD" d1="52" d2="386" d3="977"/>
# <CITE num="6" author="LIN MS" publication="J PEDIATR" d1="91" d2="222" d3="977"/>
# <CITE num="7" author="SILVERMAN M" publication="ARCH DIS CHILD" d1="53" d2="873" d3="978"/>
# <CITE num="8" author="GANIER M" publication="CLIN ALLERGY" d1="9" d2="125" d3="979"/>
# <CITE num="9" author="PRICE JF" publication="CLIN ALLERGY" d1="9" d2="563" d3="979"/>
# <CITE num="10" author="ZAMBIE MF" publication="ANN ALLERGY" d1="42" d2="290" d3="979"/>
# <CITE num="11" author="SANTAGNESE PAD" publication="AM J MED" d1="66" d2="121" d3="979"/>
# <CITE num="12" author="NELSON LA" publication="AM REV RESPIR DIS" d1="120" d2="863" d3="979"/>
# <CITE num="13" author="SLY PD" publication="AUST PAEDIATR J" d1="16" d2="205" d3="980"/>
# <CITE num="14" author="VANASPEREN PP" publication="AUST PAEDIATR J" d1="16" d2="53" d3="980"/>
# <CITE num="15" author="HODSON ME" publication="THORAX" d1="35" d2="801" d3="980"/>
# <CITE num="16" author="ORMEROD LP" publication="THORAX" d1="35" d2="768" d3="980"/>
# <CITE num="17" author="SKOV PS" publication="ALLERGY" d1="35" d2="23" d3="980"/>
# <CITE num="18" author="TACIEREUGSTER H" publication="HELV PAEDIATR ACTA" d1="35" d2="31" d3="980"/>
# <CITE num="19" author="TOBIN MJ" publication="THORAX" d1="35" d2="232" d3="980"/>
# <CITE num="20" author="TOBIN MJ" publication="THORAX" d1="35" d2="807" d3="980"/>
# <CITE num="21" author="MOSS RB" publication="AM REV RESPIR DIS" d1="121" d2="23" d3="980"/>
# <CITE num="22" author="HARPER TB" publication="LUNG" d1="157" d2="219" d3="980"/>
# <CITE num="23" author="MATTHEWS WJ" publication="N ENGL J MED" d1="302" d2="245" d3="980"/>
# <CITE num="24" author="SHEN J" publication="INFECT IMMUN" d1="32" d2="967" d3="981"/>
# <CITE num="25" author="MOSS RB" publication="J PEDIATR" d1="99" d2="215" d3="981"/>
# <CITE num="26" author="PITCHERWILMOTT RW" publication="ARCH DIS CHILD" d1="57" d2="582" d3="982"/>
# <CITE num="27" author="VOSS MJ" publication="J ALLERGY CLIN IMMUNOL" d1="69" d2="536" d3="982"/>
# <CITE num="28" author="SCHIOTZ PO" publication="ACTA PAEDIATR SCAND SUPPL 301" d1="1982" d2="55" d3="982"/>
# <CITE num="29" author="BIRX DL" publication="ANN ALLERGY" d1="53" d2="124" d3="984"/>
# <CITE num="30" author="WONNE R" publication="CLIN ALLERGY" d1="15" d2="455" d3="985"/>
# <CITE num="31" author="SIEGEL SC" publication="J ALLERGY CLIN IMMUNOL" d1="76" d2="1" d3="985"/>
# <CITE num="32" author="DARGA LL" publication="PEDIATR PULMONOL" d1="2" d2="82" d3="986"/>
# </CITATIONS>
# <RECORDNUM>00012 </RECORDNUM>
# <MEDLINENUM>74154356</MEDLINENUM>
# <AUTHORS><AUTHOR>Fluge-G</AUTHOR><AUTHOR>Aarskog-D</AUTHOR></AUTHORS>
# <TITLE>Letter: Silver-Russell dwarfism and cystic fibrosis.</TITLE>
# <SOURCE>Am-J-Dis-Child. 1974 May. 127(5). P 760-1.</SOURCE>
# <MAJORSUBJ><TOPIC>BONE-DISEASES-DEVELOPMENTAL: co</TOPIC><TOPIC>CYSTIC-FIBROSIS: co</TOPIC><TOPIC>DWARFISM:  co</TOPIC></MAJORSUBJ>
# <MINORSUBJ><TOPIC>CASE-REPORT</TOPIC><TOPIC>CHILD</TOPIC><TOPIC>FEMALE</TOPIC><TOPIC>HUMAN</TOPIC><TOPIC>SYNDROME</TOPIC></MINORSUBJ>
# <EXTRACT>Taussig et al reported a case of a 6-year-old boy with the Russell
# variant of the Silver-Russell syndrome concomitant with cystic
# fibrosis.  We would like to describe another patient who had the
# same combination of diseases.  The pattern of clinical findings in
# this patient are in accordance with that of the Silver-Russell
# syndrome.  It is, of course, possible that the development of
# cystic fibrosis in this patient is entirely accidental, although
# such a coincidence would be a statistically rare event.  The
# establishment of a possible relationship between these two
# conditions would depend on reports of other similar cases.</EXTRACT>
# <REFERENCES>
# <CITE num="001" author="TAUSSIG LM" publication="AM J DIS CHILD" d1="125" d2="495" d3="973"/>
# </REFERENCES>

# %%
doc = etree.fromstring(res[sel] + "</RECORD>")
print(etree.tostring(doc, pretty_print=True, encoding="unicode"))
# Out:
# <RECORD>
# <PAPERNUM>PN74012</PAPERNUM>
# <CITATIONS>
# <CITE num="1" author="LZEL A              PR" publication="ACTITIONER                   2" d1="14" d2="76 9" d3="5"/>
# <CITE num="2" author="WARNER JO" publication="ARCH DIS CHILD" d1="51" d2="507" d3="976"/>
# <CITE num="3" author="STERN RC" publication="J PEDIATR" d1="89" d2="406" d3="976"/>
# <CITE num="4" author="GALANT SP" publication="AM REV RESPIR DIS" d1="114" d2="325" d3="976"/>
# <CITE num="5" author="PARTINGTON MW" publication="ARCH DIS CHILD" d1="52" d2="386" d3="977"/>
# <CITE num="6" author="LIN MS" publication="J PEDIATR" d1="91" d2="222" d3="977"/>
# <CITE num="7" author="SILVERMAN M" publication="ARCH DIS CHILD" d1="53" d2="873" d3="978"/>
# <CITE num="8" author="GANIER M" publication="CLIN ALLERGY" d1="9" d2="125" d3="979"/>
# <CITE num="9" author="PRICE JF" publication="CLIN ALLERGY" d1="9" d2="563" d3="979"/>
# <CITE num="10" author="ZAMBIE MF" publication="ANN ALLERGY" d1="42" d2="290" d3="979"/>
# <CITE num="11" author="SANTAGNESE PAD" publication="AM J MED" d1="66" d2="121" d3="979"/>
# <CITE num="12" author="NELSON LA" publication="AM REV RESPIR DIS" d1="120" d2="863" d3="979"/>
# <CITE num="13" author="SLY PD" publication="AUST PAEDIATR J" d1="16" d2="205" d3="980"/>
# <CITE num="14" author="VANASPEREN PP" publication="AUST PAEDIATR J" d1="16" d2="53" d3="980"/>
# <CITE num="15" author="HODSON ME" publication="THORAX" d1="35" d2="801" d3="980"/>
# <CITE num="16" author="ORMEROD LP" publication="THORAX" d1="35" d2="768" d3="980"/>
# <CITE num="17" author="SKOV PS" publication="ALLERGY" d1="35" d2="23" d3="980"/>
# <CITE num="18" author="TACIEREUGSTER H" publication="HELV PAEDIATR ACTA" d1="35" d2="31" d3="980"/>
# <CITE num="19" author="TOBIN MJ" publication="THORAX" d1="35" d2="232" d3="980"/>
# <CITE num="20" author="TOBIN MJ" publication="THORAX" d1="35" d2="807" d3="980"/>
# <CITE num="21" author="MOSS RB" publication="AM REV RESPIR DIS" d1="121" d2="23" d3="980"/>
# <CITE num="22" author="HARPER TB" publication="LUNG" d1="157" d2="219" d3="980"/>
# <CITE num="23" author="MATTHEWS WJ" publication="N ENGL J MED" d1="302" d2="245" d3="980"/>
# <CITE num="24" author="SHEN J" publication="INFECT IMMUN" d1="32" d2="967" d3="981"/>
# <CITE num="25" author="MOSS RB" publication="J PEDIATR" d1="99" d2="215" d3="981"/>
# <CITE num="26" author="PITCHERWILMOTT RW" publication="ARCH DIS CHILD" d1="57" d2="582" d3="982"/>
# <CITE num="27" author="VOSS MJ" publication="J ALLERGY CLIN IMMUNOL" d1="69" d2="536" d3="982"/>
# <CITE num="28" author="SCHIOTZ PO" publication="ACTA PAEDIATR SCAND SUPPL 301" d1="1982" d2="55" d3="982"/>
# <CITE num="29" author="BIRX DL" publication="ANN ALLERGY" d1="53" d2="124" d3="984"/>
# <CITE num="30" author="WONNE R" publication="CLIN ALLERGY" d1="15" d2="455" d3="985"/>
# <CITE num="31" author="SIEGEL SC" publication="J ALLERGY CLIN IMMUNOL" d1="76" d2="1" d3="985"/>
# <CITE num="32" author="DARGA LL" publication="PEDIATR PULMONOL" d1="2" d2="82" d3="986"/>
# </CITATIONS>
# <RECORDNUM>00012 </RECORDNUM>
# <MEDLINENUM>74154356</MEDLINENUM>
# <AUTHORS><AUTHOR>Fluge-G</AUTHOR><AUTHOR>Aarskog-D</AUTHOR></AUTHORS>
# <TITLE>Letter: Silver-Russell dwarfism and cystic fibrosis.</TITLE>
# <SOURCE>Am-J-Dis-Child. 1974 May. 127(5). P 760-1.</SOURCE>
# <MAJORSUBJ><TOPIC>BONE-DISEASES-DEVELOPMENTAL: co</TOPIC><TOPIC>CYSTIC-FIBROSIS: co</TOPIC><TOPIC>DWARFISM:  co</TOPIC></MAJORSUBJ>
# <MINORSUBJ><TOPIC>CASE-REPORT</TOPIC><TOPIC>CHILD</TOPIC><TOPIC>FEMALE</TOPIC><TOPIC>HUMAN</TOPIC><TOPIC>SYNDROME</TOPIC></MINORSUBJ>
# <EXTRACT>Taussig et al reported a case of a 6-year-old boy with the Russell
# variant of the Silver-Russell syndrome concomitant with cystic
# fibrosis.  We would like to describe another patient who had the
# same combination of diseases.  The pattern of clinical findings in
# this patient are in accordance with that of the Silver-Russell
# syndrome.  It is, of course, possible that the development of
# cystic fibrosis in this patient is entirely accidental, although
# such a coincidence would be a statistically rare event.  The
# establishment of a possible relationship between these two
# conditions would depend on reports of other similar cases.</EXTRACT>
# <REFERENCES>
# <CITE num="001" author="TAUSSIG LM" publication="AM J DIS CHILD" d1="125" d2="495" d3="973"/>
# </REFERENCES>
#
# </RECORD>

# %%
json_doc = {
    "paper_number": doc.xpath("//PAPERNUM/text()")[0],
    "record_number": doc.xpath("//RECORDNUM/text()")[0],
    "medline_num": doc.xpath("//MEDLINENUM/text()")[0],
    "authors": doc.xpath("//AUTHORS/AUTHOR/text()"),
    "title": doc.xpath("//TITLE/text()")[0],
    "source": doc.xpath("//SOURCE/text()")[0],
    "major_subjects": doc.xpath("//MAJORSUBJ/TOPIC/text()"),
    "minor_subjects": doc.xpath("//MINORSUBJ/TOPIC/text()"),
    "abstract": (doc.xpath("//ABSTRACT/text()") + doc.xpath("//EXTRACT/text()"))[0],
    "citations": [{
            "author": cite.attrib["author"],
            "publication": cite.attrib["publication"],
            "d1": cite.attrib["d1"],
            "d2": cite.attrib["d2"],
            "d3": cite.attrib["d3"]
        }
    
        for cite in doc.xpath("//CITATIONS/CITE")
            
    ],
    "references": [{
            "author": cite.attrib["author"],
            "publication": cite.attrib["publication"],
            "d1": cite.attrib["d1"],
            "d2": cite.attrib["d2"],
            "d3": cite.attrib["d3"]
        }

        for cite in doc.xpath("//REFERENCES/CITE")
    ]
}

print(json.dumps(json_doc, indent="\t"))
# Out:
# {
# 	"paper_number": "PN74012",
# 	"record_number": "00012 ",
# 	"medline_num": "74154356",
# 	"authors": [
# 		"Fluge-G",
# 		"Aarskog-D"
# 	],
# 	"title": "Letter: Silver-Russell dwarfism and cystic fibrosis.",
# 	"source": "Am-J-Dis-Child. 1974 May. 127(5). P 760-1.",
# 	"major_subjects": [
# 		"BONE-DISEASES-DEVELOPMENTAL: co",
# 		"CYSTIC-FIBROSIS: co",
# 		"DWARFISM:  co"
# 	],
# 	"minor_subjects": [
# 		"CASE-REPORT",
# 		"CHILD",
# 		"FEMALE",
# 		"HUMAN",
# 		"SYNDROME"
# 	],
# 	"abstract": "Taussig et al reported a case of a 6-year-old boy with the Russell\nvariant of the Silver-Russell syndrome concomitant with cystic\nfibrosis.  We would like to describe another patient who had the\nsame combination of diseases.  The pattern of clinical findings in\nthis patient are in accordance with that of the Silver-Russell\nsyndrome.  It is, of course, possible that the development of\ncystic fibrosis in this patient is entirely accidental, although\nsuch a coincidence would be a statistically rare event.  The\nestablishment of a possible relationship between these two\nconditions would depend on reports of other similar cases.",
# 	"citations": [
# 		{
# 			"author": "LZEL A              PR",
# 			"publication": "ACTITIONER                   2",
# 			"d1": "14",
# 			"d2": "76 9",
# 			"d3": "5"
# 		},
# 		{
# 			"author": "WARNER JO",
# 			"publication": "ARCH DIS CHILD",
# 			"d1": "51",
# 			"d2": "507",
# 			"d3": "976"
# 		},
# 		{
# 			"author": "STERN RC",
# 			"publication": "J PEDIATR",
# 			"d1": "89",
# 			"d2": "406",
# 			"d3": "976"
# 		},
# 		{
# 			"author": "GALANT SP",
# 			"publication": "AM REV RESPIR DIS",
# 			"d1": "114",
# 			"d2": "325",
# 			"d3": "976"
# 		},
# 		{
# 			"author": "PARTINGTON MW",
# 			"publication": "ARCH DIS CHILD",
# 			"d1": "52",
# 			"d2": "386",
# 			"d3": "977"
# 		},
# 		{
# 			"author": "LIN MS",
# 			"publication": "J PEDIATR",
# 			"d1": "91",
# 			"d2": "222",
# 			"d3": "977"
# 		},
# 		{
# 			"author": "SILVERMAN M",
# 			"publication": "ARCH DIS CHILD",
# 			"d1": "53",
# 			"d2": "873",
# 			"d3": "978"
# 		},
# 		{
# 			"author": "GANIER M",
# 			"publication": "CLIN ALLERGY",
# 			"d1": "9",
# 			"d2": "125",
# 			"d3": "979"
# 		},
# 		{
# 			"author": "PRICE JF",
# 			"publication": "CLIN ALLERGY",
# 			"d1": "9",
# 			"d2": "563",
# 			"d3": "979"
# 		},
# 		{
# 			"author": "ZAMBIE MF",
# 			"publication": "ANN ALLERGY",
# 			"d1": "42",
# 			"d2": "290",
# 			"d3": "979"
# 		},
# 		{
# 			"author": "SANTAGNESE PAD",
# 			"publication": "AM J MED",
# 			"d1": "66",
# 			"d2": "121",
# 			"d3": "979"
# 		},
# 		{
# 			"author": "NELSON LA",
# 			"publication": "AM REV RESPIR DIS",
# 			"d1": "120",
# 			"d2": "863",
# 			"d3": "979"
# 		},
# 		{
# 			"author": "SLY PD",
# 			"publication": "AUST PAEDIATR J",
# 			"d1": "16",
# 			"d2": "205",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "VANASPEREN PP",
# 			"publication": "AUST PAEDIATR J",
# 			"d1": "16",
# 			"d2": "53",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "HODSON ME",
# 			"publication": "THORAX",
# 			"d1": "35",
# 			"d2": "801",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "ORMEROD LP",
# 			"publication": "THORAX",
# 			"d1": "35",
# 			"d2": "768",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "SKOV PS",
# 			"publication": "ALLERGY",
# 			"d1": "35",
# 			"d2": "23",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "TACIEREUGSTER H",
# 			"publication": "HELV PAEDIATR ACTA",
# 			"d1": "35",
# 			"d2": "31",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "TOBIN MJ",
# 			"publication": "THORAX",
# 			"d1": "35",
# 			"d2": "232",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "TOBIN MJ",
# 			"publication": "THORAX",
# 			"d1": "35",
# 			"d2": "807",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "MOSS RB",
# 			"publication": "AM REV RESPIR DIS",
# 			"d1": "121",
# 			"d2": "23",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "HARPER TB",
# 			"publication": "LUNG",
# 			"d1": "157",
# 			"d2": "219",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "MATTHEWS WJ",
# 			"publication": "N ENGL J MED",
# 			"d1": "302",
# 			"d2": "245",
# 			"d3": "980"
# 		},
# 		{
# 			"author": "SHEN J",
# 			"publication": "INFECT IMMUN",
# 			"d1": "32",
# 			"d2": "967",
# 			"d3": "981"
# 		},
# 		{
# 			"author": "MOSS RB",
# 			"publication": "J PEDIATR",
# 			"d1": "99",
# 			"d2": "215",
# 			"d3": "981"
# 		},
# 		{
# 			"author": "PITCHERWILMOTT RW",
# 			"publication": "ARCH DIS CHILD",
# 			"d1": "57",
# 			"d2": "582",
# 			"d3": "982"
# 		},
# 		{
# 			"author": "VOSS MJ",
# 			"publication": "J ALLERGY CLIN IMMUNOL",
# 			"d1": "69",
# 			"d2": "536",
# 			"d3": "982"
# 		},
# 		{
# 			"author": "SCHIOTZ PO",
# 			"publication": "ACTA PAEDIATR SCAND SUPPL 301",
# 			"d1": "1982",
# 			"d2": "55",
# 			"d3": "982"
# 		},
# 		{
# 			"author": "BIRX DL",
# 			"publication": "ANN ALLERGY",
# 			"d1": "53",
# 			"d2": "124",
# 			"d3": "984"
# 		},
# 		{
# 			"author": "WONNE R",
# 			"publication": "CLIN ALLERGY",
# 			"d1": "15",
# 			"d2": "455",
# 			"d3": "985"
# 		},
# 		{
# 			"author": "SIEGEL SC",
# 			"publication": "J ALLERGY CLIN IMMUNOL",
# 			"d1": "76",
# 			"d2": "1",
# 			"d3": "985"
# 		},
# 		{
# 			"author": "DARGA LL",
# 			"publication": "PEDIATR PULMONOL",
# 			"d1": "2",
# 			"d2": "82",
# 			"d3": "986"
# 		}
# 	],
# 	"references": [
# 		{
# 			"author": "TAUSSIG LM",
# 			"publication": "AM J DIS CHILD",
# 			"d1": "125",
# 			"d2": "495",
# 			"d3": "973"
# 		}
# 	]
# }
