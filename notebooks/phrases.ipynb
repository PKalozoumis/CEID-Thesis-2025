# %%
from gensim.models.phrases import Phrases
from gensim.utils import simple_preprocess

# %%
phrase_model = Phrases.load("../models/phrase_model.pkl")
print(type(phrase_model))
# Out:
# <class 'gensim.models.phrases.Phrases'>

# %%
phrases = phrase_model.export_phrases()

for phrase, score in phrases.items():
    print(f"{phrase}:\t\t{score}")

print(phrase_model[simple_preprocess("Kris, I remember you're cystic fibrosis")])
#print(list(phrase_model.analyze_sentence(simple_preprocess("Kris, I remember you're cystic fibrosis"))))
# Out:
# short_term:		21.269917731110628
# power_spectrum:		78.58677665291839
# statistically_significant:		93.10187159440892
# time_interval:		27.354208984313207
# northern_hemisphere:		1535.08984375
# solar_cycle:		55.85053768534748
# circular_polarization:		104.80245349689979
# gravitational_wave:		83.5423044217687
# supermassive_black:		479.668733522117
# black_hole:		513.5773911622969
# hole_binaries:		39.41931730412366
# cosmic_strings:		120.56912315150028
# early_universe:		92.62156287644686
# pulsar_timing:		118.19037593984962
# circularly_polarized:		850.6125541125541
# gravitational_waves:		174.85598599905077
# long_range:		81.339008900073
# coulomb_interaction:		101.87095072940502
# atomic_nuclei:		15.908632729480821
# good_agreement:		460.1031174640898
# molecular_dynamics:		71.2910496836663
# monte_carlo:		1499.1111755371094
# loop_integrals:		51.67089606206035
# expressed_in_terms:		272.88763335648
# pacs_numbers:		902.8769955817378
# institut_fr:		3902.5124131082425
# ...
